# %%
import xarray as xr
import numpy as np

# %%
# argo = xr.open_dataset('1902381_Sprof.nc')
# argo
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/xarray/backends/file_manager.py:219, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     218 try:
# --> 219     file = self._cache[self._key]
#     220 except KeyError:
#
# File ~/.local/lib/python3.12/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'h5netcdf.core.File'>, ('/etc/ecmwf/nfs/dh2_home_b/bel7512/bcz1d/Shiny-python/data/1902381_Sprof.nc',), 'r', (('decode_vlen_strings', True), ('driver', None), ('invalid_netcdf', None), ('phony_dims', 'access')), 'd17b4e47-5491-4f18-8572-7aff1c99fd4f']
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
ds = xr.load_dataset('1902381_result.nc')
ds
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:            (time: 332, z: 30, lat: 1, lon: 1, zi: 31)
# Coordinates:
#     zi                 (time, zi, lat, lon) float32 41kB -600.0 ... -9.415e-14
#     z                  (time, z, lat, lon) float32 40kB -586.9 -560.7 ... -5.656
#   * time               (time) datetime64[ns] 3kB 2023-01-03 ... 2023-11-30
#   * lon                (lon) float32 4B -35.0
#   * lat                (lat) float32 4B 16.0
# Data variables: (12/30)
#     total_chlorophyll  (time, z, lat, lon) float32 40kB 0.269 0.269 ... 0.02894
#     carbonate_Cflx     (time, lat, lon) float32 1kB -5.464e-08 ... -1.81e-08
#     carbonate_DIC      (time, z, lat, lon) float32 40kB 0.00199 ... 0.001964
#     zoo_prod           (time, z, lat, lon) float32 40kB 9.31e-11 ... 5.279e-12
#     mes_prod           (time, z, lat, lon) float32 40kB 8.123e-11 ... 5.08e-13
#     zoo_c              (time, z, lat, lon) float32 40kB 6.07e-07 ... 2.467e-08
#     ...                 ...
# ...

# %%
# Get your variable
var_data = ds['total_chlorophyll']

# Extract coordinates
time = ds['time'].values
z = ds['z'].values

# Select first lat/lon point if spatial dimensions exist
if var_data.ndim == 4:  # (time, z, lat, lon)
    var_data = var_data[:, :, 0, 0]
elif var_data.ndim == 3:  # (time, z, something)
    var_data = var_data[:, :, 0]

# Now flatten
time_flat = np.repeat(time, len(z))
z_flat = np.tile(z, len(time))
values_flat = var_data.values.flatten()

# Remove NaNs
mask = ~np.isnan(values_flat)

# Create plot
fig, ax = plt.subplots(figsize=(10, 6))

sc = ax.scatter(time_flat[mask], z_flat[mask], c=values_flat[mask], 
                cmap='viridis', s=20)

ax.invert_yaxis()
ax.set_xlabel('Time')
ax.set_ylabel('Depth (m)')
plt.colorbar(sc, ax=ax)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 15
#      12     var_data = var_data[:, :, 0]
#      14 # Now flatten
# ---> 15 time_flat = np.repeat(time, len(z))
#      16 z_flat = np.tile(z, len(time))
#      17 values_flat = var_data.values.flatten()
#
# NameError: name 'np' is not defined
